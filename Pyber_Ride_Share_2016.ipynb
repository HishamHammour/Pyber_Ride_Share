# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

# %%
# Read the City and Ride Data
city_data_df = pd.read_csv(city_data_to_load)
#city_data_df.head()

ride_data_df = pd.read_csv(ride_data_to_load)
#ride_data_df.head()

# %%
# Combine the data into a single dataset
combined_pyber_data = pd.merge(ride_data_df, city_data_df, how= "left")

# %%
# Display the data table for preview
combined_pyber_data.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2018-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Obtain the x and y coordinates for each of the three city types

# Build the scatter plots for each city types

# Incorporate the other graph properties

# Create a legend

# Incorporate a text label regarding circle size

# Save Figure

# %%
urban_df = combined_pyber_data.loc[(combined_pyber_data["type"] == "Urban")]
suburban_df = combined_pyber_data.loc[(combined_pyber_data["type"] == "Suburban")]
rural_df = combined_pyber_data.loc[(combined_pyber_data["type"] == "Rural")]

# %%
# Calculations needed:
#   Average Fare, total number of rides, and drivers for each type.

# %%
#Urban 
avg_fare_urban = urban_df.groupby(['city'])['fare'].mean()
total_rides_urban = urban_df.groupby(['city']).count()['ride_id']
total_drivers_urban = urban_df.groupby(['city'])['driver_count'].value_counts()

# %%
#Suburban
avg_fare_suburban = suburban_df.groupby(['city'])['fare'].mean()
total_rides_suburban = suburban_df.groupby(['city']).count()['ride_id']
total_drivers_suburban = suburban_df.groupby(['city'])['driver_count'].value_counts()

# %%
#Rural
avg_fare_rural_city = rural_df.groupby(['city'])['fare'].mean()
total_rides_rural_city = rural_df.groupby(['city']).count()['ride_id']
total_drivers_rural_city = rural_df.groupby(['city'])['driver_count'].value_counts()

# %%
#color Gold, Light Sky Blue, and Light Coral
plt.scatter(total_rides_urban, avg_fare_urban, s=total_drivers_urban*10,
            marker ='o', facecolors ="coral", edgecolors='black',alpha = 0.8, label="Urban")

plt.scatter(total_rides_suburban, avg_fare_suburban,s=total_drivers_suburban*10,
            marker ='o', facecolors ="skyblue", edgecolors='black',alpha = 0.8, label="Suburban")

plt.scatter(total_rides_rural_city, avg_fare_rural_city,s=total_drivers_rural_city*10,
            marker ='o', facecolors ="gold", edgecolors='black',alpha = 0.8, label="Rural")


# Adding the chart title, x label, y label, and legend 

plt.title("Pyber Ride Sharing Data (2016)")

plt.xlabel("Total Numbers of Rides (Per City))")

plt.ylabel("Average Fare($)")

plt.legend(title= 'City Type' , loc=1)
plt.grid(True)
plt.savefig("Pyber_Ride_Sharing_Data_2016.png")
plt.show()

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percents
# Build Pie Chart
# Save Figure

# %%
# Calculate Type Percents
total_fares = combined_pyber_data.groupby(['type'])['fare'].sum()
# Labels for the sections of our pie chart
labels = ["Rural","Suburban","Urban" ]
# The colors of each section of the pie chart
colors = ["gold","lightskyblue","lightcoral"]
explode = (0, 0, 0.1)
plt.title("% of Total Fares By City Type")
plt.pie(total_fares, explode=explode, labels=labels, colors=colors,
        autopct="%1.2f%%",shadow=True, startangle=160)
plt.axis("equal")
plt.savefig("Total_Fares_By_City_Type.png")
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Ride Percents

# Build Pie Chart

# Save Figure

# %%
# Calculate Total Fare by City Type
total_rides = combined_pyber_data.groupby(['type'])['ride_id'].count()
# Labels for the sections of our pie chart
labels = ["Rural","Suburban","Urban" ]
# The colors of each section of the pie chart
colors = ["gold","lightskyblue","lightcoral"]
explode = (0, 0, 0.1)
plt.title("% of Total Rides By City Types")
plt.pie(total_rides, explode=explode, labels=labels, colors=colors,
        autopct="%1.2f%%", shadow=True, startangle=140)
plt.axis("equal")
plt.savefig("Total_Rides_By_City_Types.png")
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Driver Percents
# Build Pie Charts
# Save Figure

# %%
# Calculate Total Drivers by City Type
total_drivers = city_data_df.groupby(['type'])['driver_count'].sum()
# Labels for the sections of our pie chart
labels = ["Rural","Suburban","Urban" ]
# The colors of each section of the pie chart
colors = ["gold","lightskyblue","lightcoral"]
explode = (0, 0, 0.1)
plt.title("% of Total Drivers By City Types")
plt.pie(total_drivers, explode=explode, labels=labels, colors=colors,
        autopct="%1.2f%%", shadow=True, startangle=140)
plt.axis("equal")
plt.savefig("Total_Drivers_By_City_Types.png")
plt.show()
